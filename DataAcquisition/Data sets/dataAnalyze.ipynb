# %% [markdown]
# Display data recordec for collision detection
# in the folder:
# C:\Users\estek\OneDrive\Collison Detection\collision-detection\DataAcquisition\Data sets

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import io
import glob

# %% [markdown]
# Read text files
# first

# %%
path = r'Dataset1/*.log'
files = glob.glob (path)
print(files)
print(len(files))
# Out:
# ['Dataset1\\collDetect_DataAq_f10.000000N_CollTypeAccidntal6May2023_114438.log', 'Dataset1\\collDetect_DataAq_f10.000000N_CollTypeIntentional6May2023_113937.log', 'Dataset1\\collDetect_DataAq_f10.000000N_CollTypeNoColl6May2023_113350.log', 'Dataset1\\collDetect_DataAq_f15.000000N_CollTypeAccidntal6May2023_11438.log', 'Dataset1\\collDetect_DataAq_f15.000000N_CollTypeIntentional6May2023_11369.log', 'Dataset1\\collDetect_DataAq_f15.000000N_CollTypeNoColl6May2023_113138.log']
# 6

# %%
#read_file = pd.read_csv (r'Dataset1/collDetect_DataAq_f15.000000N_CollTypeIntentional6May2023_11369.log',delim_whitespace=True)
with open('Dataset1/collDetect_DataAq_f15.000000N_CollTypeIntentional6May2023_11369.log', 'r+') as f:
    file_str = f.read()
    # Removing the character '%' that KUKA generates in the beginning of the log files
    file_str2 = file_str[1:]
    data = pd.read_csv (io.StringIO(file_str2),delim_whitespace=True)
    print(data.shape)   
data.head()
# Out:
#
# (30000, 34)
#     ZeitInSec  ZeitInNanoSec  axisTauExtMsr_LBR_iiwa_14_R820_1[0]  \
# 0  1683419776      438000000                            -0.041420
# 1  1683419776      439000000                            -0.045048
# 2  1683419776      440000000                            -0.045373
# 3  1683419776      441000000                            -0.045306
# 4  1683419776      442000000                            -0.049433
#
#    axisTauExtMsr_LBR_iiwa_14_R820_1[1]  axisTauExtMsr_LBR_iiwa_14_R820_1[2]  \
# 0                            -0.174446                            -0.131150
# 1                            -0.172815                            -0.131915
# 2                            -0.172770                            -0.132220
# 3                            -0.172818                            -0.132395
# 4                            -0.172889                            -0.133768
#
#    axisTauExtMsr_LBR_iiwa_14_R820_1[3]  axisTauExtMsr_LBR_iiwa_14_R820_1[4]  \
# ...
